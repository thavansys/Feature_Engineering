# %% [markdown]
# ## 5 Number Summary and Box Plot

# %%
 import numpy as np

# %%
first_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,Q1,median,Q3,maximum=np.quantile(first_marks,[0,0.25,0.5,0.75,1])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*IQR
upper_fence=Q3+1.5*IQR

# %%
lower_fence,upper_fence
# Out:
# (np.float64(1.5), np.float64(141.5))

# %%
first_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
import seaborn as sns

sns.boxplot(first_marks)
# Out:
# <Axes: >

# %%
second_marks=[-100,-200,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
minimum,Q1,median,Q3,maximum=np.quantile(second_marks,[0,0.25,0.5,0.75,1])
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(-200.0),
#  np.float64(47.25),
#  np.float64(70.5),
#  np.float64(89.75),
#  np.float64(180.0))

# %%
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
IQR,lower_bound,upper_bound
# Out:
# (np.float64(42.5), np.float64(-16.5), np.float64(153.5))

# %%
sns.boxplot(second_marks)
# Out:
# <Axes: >
