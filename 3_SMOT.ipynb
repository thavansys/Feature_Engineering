# %% [markdown]
# ## SMOTE (Synthetic Minority Oversampling Technique)

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_redundant=0,n_features=2,n_clusters_per_class=1,
                        weights=[0.90],random_state=12)

# %%
import pandas as pd
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (from imblearn) (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (from imbalanced-learn->imblearn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (from imbalanced-learn->imblearn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (from imbalanced-learn->imblearn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /home/thavan-lin-ai/anaconda3/lib/python3.13/site-packages (from imbalanced-learn->imblearn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample=SMOTE()

# %%
X,y=oversample.fit_resample(final_df[['f1','f2']],final_df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
y.shape
# Out:
# (1800,)

# %%
len(y[y==0]),len(y[y==1])
# Out:
# (900, 900)

# %%
df1=pd.DataFrame(X,columns=['f1','f2'])
df2=pd.DataFrame(y,columns=['target'])
final_df=pd.concat([df1,df2],axis=1)

# %%
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['target'])
